# %%
import pandas as pd
import numpy as np

# %%
# Read Excel Files
ca_2017_df = pd.DataFrame(pd.read_excel("Data/california_2017.xls"))
ca_2018_df = pd.DataFrame(pd.read_excel("Data/california_2018.xls"))
ca_2019_df = pd.DataFrame(pd.read_excel("Data/california_2019.xls"))

# view dataframes
display(ca_2017_df)
display(ca_2018_df)
display(ca_2019_df)
# Out:
#                                                Table 8  Unnamed: 1  \
# 0                                           CALIFORNIA         NaN
# 1                    Offenses Known to Law Enforcement         NaN
# 2                                        by City, 2017         NaN
# 3                                                 City  Population
# 4                                             Adelanto       34491
# ..                                                 ...         ...
# 457                                              Yreka        7527
# 458                                          Yuba City       67164
# 459                                            Yucaipa       53964
# 460                                       Yucca Valley       21858
# 461  1 The figures shown in this column for the off...         NaN
#
#          Unnamed: 2                              Unnamed: 3 Unnamed: 4  \
# 0               NaN                                     NaN        NaN
# ...

# %% [markdown]
# ## Clean ca_2017_df

# %%
# clean rows
cleaned_ca_2017_df_1 = ca_2017_df.drop(labels=[0, 1, 2, 3, 460, 461], axis=0)

# rename column headers
renamed_ca_2017_df = cleaned_ca_2017_df_1.rename(columns = {'Table 8': 'City', 
                                                            'Unnamed: 1': 'Population', 
                                                            'Unnamed: 2': 'Violent crime', 
                                                            "Unnamed: 3": "Murder",
                                                            "Unnamed: 4": "Rape", 
                                                            'Unnamed: 5': 'Robbery',
                                                            'Unnamed: 6': 'Aggravated assault',
                                                            'Unnamed: 7': 'Property crime', 
                                                            'Unnamed: 8': 'Burglary',
                                                            'Unnamed: 9': 'Larceny-theft', 
                                                            'Unnamed: 10': 'Motor vehicle theft',
                                                            'Unnamed: 11': 'Arson'})

# reset index
cleaned_ca_2017_df = renamed_ca_2017_df.reset_index(drop=True)

# print dataframe
cleaned_ca_2017_df
# Out:
#              City Population Violent crime Murder Rape Robbery  \
# 0        Adelanto      34491           276      1   20      42
# 1    Agoura Hills      20490            21      0    6       4
# 2         Alameda      78907           162      0    7      94
# 3          Albany      20083            40      0    8      21
# 4        Alhambra      84837           161      2   11      89
# ..            ...        ...           ...    ...  ...     ...
# 451   Yorba Linda      68225            42      0    3      17
# 452    Yountville       2988             5      0    0       0
# 453         Yreka       7527            28      0    0       1
# 454     Yuba City      67164           241      3   28      52
# 455       Yucaipa      53964           200      3   14      31
#
#     Aggravated assault Property crime Burglary Larceny-theft  \
# 0                  213            459      136           209
# 1                   11            306       66           223
# ...

# %% [markdown]
# ## Clean ca_2018_df

# %%
# clean rows
cleaned_ca_2018_df_1 = ca_2018_df.drop(labels=[0, 1, 2, 3, 465, 466], axis=0)

# rename column headers
renamed_ca_2018_df = cleaned_ca_2018_df_1.rename(columns = {'Table 8': 'City', 
                                                            'Unnamed: 1': 'Population', 
                                                            'Unnamed: 2': 'Violent crime', 
                                                            "Unnamed: 3": "Murder",
                                                            "Unnamed: 4": "Rape", 
                                                            'Unnamed: 5': 'Robbery',
                                                            'Unnamed: 6': 'Aggravated assault',
                                                            'Unnamed: 7': 'Property crime', 
                                                            'Unnamed: 8': 'Burglary',
                                                            'Unnamed: 9': 'Larceny-theft', 
                                                            'Unnamed: 10': 'Motor vehicle theft',
                                                            'Unnamed: 11': 'Arson'})

# reset index
cleaned_ca_2018_df = renamed_ca_2018_df.reset_index(drop=True)

# print dataframe
cleaned_ca_2018_df
# Out:
#              City Population Violent crime Murder Rape Robbery  \
# 0        Adelanto      34429           239      0   25      40
# 1    Agoura Hills      20744            27      0    5       8
# 2         Alameda      79951           184      1   13      75
# 3          Albany      20379            37      1    2      28
# 4        Alhambra      85718           193      3   14      88
# ..            ...        ...           ...    ...  ...     ...
# 456    Yountville       2921             2      0    1       0
# 457         Yreka       7573            37      0    2       2
# 458     Yuba City      67035           264      1   35      75
# 459       Yucaipa      54001           101      0   12      29
# 460  Yucca Valley      21895            85      2    8      21
#
#     Aggravated assault Property crime Burglary Larceny-theft  \
# 0                  174            610      175           336
# 1                   14            274       64           186
# ...

# %% [markdown]
# ## Clean ca_2018_df

# %%
# clean rows
cleaned_ca_2019_df_1 = ca_2019_df.drop(labels=[0, 1, 2, 3, 465, 466], axis=0)

# rename column headers
renamed_ca_2019_df = cleaned_ca_2019_df_1.rename(columns = {'Table 8': 'City', 
                                                            'Unnamed: 1': 'Population', 
                                                            'Unnamed: 2': 'Violent crime', 
                                                            "Unnamed: 3": "Murder",
                                                            "Unnamed: 4": "Rape", 
                                                            'Unnamed: 5': 'Robbery',
                                                            'Unnamed: 6': 'Aggravated assault',
                                                            'Unnamed: 7': 'Property crime', 
                                                            'Unnamed: 8': 'Burglary',
                                                            'Unnamed: 9': 'Larceny-theft', 
                                                            'Unnamed: 10': 'Motor vehicle theft',
                                                            'Unnamed: 11': 'Arson'})

# reset index
cleaned_ca_2019_df = renamed_ca_2019_df.reset_index(drop=True)

# print dataframe
cleaned_ca_2019_df
# Out:
#              City Population Violent crime Murder Rape Robbery  \
# 0        Adelanto      34429           239      0   25      40
# 1    Agoura Hills      20744            27      0    5       8
# 2         Alameda      79951           184      1   13      75
# 3          Albany      20379            37      1    2      28
# 4        Alhambra      85718           193      3   14      88
# ..            ...        ...           ...    ...  ...     ...
# 456    Yountville       2921             2      0    1       0
# 457         Yreka       7573            37      0    2       2
# 458     Yuba City      67035           264      1   35      75
# 459       Yucaipa      54001           101      0   12      29
# 460  Yucca Valley      21895            85      2    8      21
#
#     Aggravated assault Property crime Burglary Larceny-theft  \
# 0                  174            610      175           336
# 1                   14            274       64           186
# ...
